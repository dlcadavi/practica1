# %%
# @title Python y Librerías
import sys
print(f"Versión de Python utilizada: {sys.version.split()[0]}")










import pandas as pd
import numpy as np
print(f"Versión de Pandas utilizada: {pd.__version__}")
print(f"Versión de Numpy: {np.__version__}")
# Out:
# Versión de Python utilizada: 3.10.19
# Versión de Pandas utilizada: 2.3.3
# Versión de Numpy: 2.2.5

# %%
# !ls
# Out:
# P1.ipynb  ensayo.txt

# %%
# Ver en qué carpeta estoy parado y qué hay adentro
import os
print("📍 Ubicación actual:", os.getcwd())
print("📂 Archivos disponibles:", os.listdir())
# Out:
# 📍 Ubicación actual: /home/lorenca/Descargas/practica1
# 📂 Archivos disponibles: ['P1.ipynb', 'ensayo.txt']

# %%
# Ruta típica: '/content/drive/MyDrive/NOMBRE_DE_TU_CARPETA'
ruta = '/home/lorenca/Descargas/practica1'
os.chdir(ruta)

# !ls
# Out:
# P1.ipynb  ensayo.txt

# %%
# Instalar librerías (ejemplo para conectarse con MySQL)
# !pip install pymysql -q

# %%
# -----------------------------------------------
# 1. Creamos un archivo de texto simple
con_este_texto = "Texto modificado"

# %%
# -----------------------------------------------
# Descargar en la carpeta donde estemos trabajando, incluso una de Drive
with open('hola_en_local.txt', 'w') as archivo:
    archivo.write(con_este_texto)

# %%
ruta = '/content/'
os.chdir(ruta)

# %%
with open('hola.txt', 'w') as archivo:
    archivo.write(con_este_texto)

# %%
nuevo_texto = "\nEsta es una segunda línea que añadimos después."

# %%
# 2. Abrimos el archivo con 'a' (Append)
with open('hola.txt', 'a') as archivo:
    archivo.write("La tercera línea")

# %%
# 1. Cree una lista con los nombres de 5 ciudades de su región
ciudades_principales = ["Medellín", "Cali", "Barranquilla", "Cartagena", "Bucaramanga"]

# 2. Imprima la lista completa para verificar:
print(f"Lista completa: {ciudades_principales}")

# 3. Imprima el TERCER elemento de la lista
# (El tercer elemento está en el índice 2)
print(f"El tercer elemento es: {ciudades_principales[2]}")
# Out:
# Lista completa: ['Medellín', 'Cali', 'Barranquilla', 'Cartagena', 'Bucaramanga']
# El tercer elemento es: Barranquilla
